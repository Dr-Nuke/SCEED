# %%
import pandas as pd
import numpy as np

# importthe samll data base
sd= pd.read_csv('C:\\Users\\ChrisBo\\Documents\\GitHub\\CSChallange\\small.csv')

sd.head()
# Out:
#         cif  category     turnover  transaction_count  io_ratio  age  \
# 0  90000000         0    217673.05                125  0.304000   40
# 1  90000001         0        57.42                 20  0.250000   17
# 2  90000002         0   1465076.90                  1  0.000000   66
# 3  90000003         0    429840.54                 46  0.239130   43
# 4  90000004         2  93356190.65                 63  0.365079    0
#
#    nationality  is_pep  inactive_days_average  inactive_days_max  \
# 0          123       0                   1.66                 88
# 1           90       0                   7.32                 88
# 2          123       0                  24.08                 25
# 3           90       0                   3.88                 86
# 4          186       0                   2.77                100
#
#    n_of_accounts  distinct_counterparties  channel_risk  atm_withdrawal  \
# 0              1                        3      0.254742         1937.15
# ...

# %%
cpi= pd.read_csv('C:\\Users\\ChrisBo\\Documents\\GitHub\\CSChallange\\2018_CPI_FullDataSet_modCHris.csv', sep=';')
cpi.head()
# Out:
#        Country ISO3 Region  CPI Score 2018  Rank   Standard error  \
# 0      Denmark  DNK  WE/EU              88      1            2.63
# 1  New Zealand  NZL     AP              87      2            2.44
# 2      Finland  FIN  WE/EU              85      3            2.74
# 3    Singapore  SGP     AP              85      3            1.98
# 4       Sweden  SWE  WE/EU              85      3            2.02
#
#    Number of sources  Upper CI  Lower CI   African Development Bank CPIA  \
# 0                  8        92         84                            NaN
# 1                  8        91         83                            NaN
# 2                  8        89         81                            NaN
# 3                  9        88         82                            NaN
# 4                  8        88         82                            NaN
#
#                 ...                \
# 0               ...
# 1               ...
# 2               ...
# 3               ...
# ...

# %%
# add the rank column
len(sd)
a=np.zeros([len(sd),1])
sd['Rank'] = a
sd.head()
# Out:
#         cif  category     turnover  transaction_count  io_ratio  age  \
# 0  90000000         0    217673.05                125  0.304000   40
# 1  90000001         0        57.42                 20  0.250000   17
# 2  90000002         0   1465076.90                  1  0.000000   66
# 3  90000003         0    429840.54                 46  0.239130   43
# 4  90000004         2  93356190.65                 63  0.365079    0
#
#    nationality  is_pep  inactive_days_average  inactive_days_max  \
# 0          123       0                   1.66                 88
# 1           90       0                   7.32                 88
# 2          123       0                  24.08                 25
# 3           90       0                   3.88                 86
# 4          186       0                   2.77                100
#
#    n_of_accounts  distinct_counterparties  channel_risk  atm_withdrawal  \
# 0              1                        3      0.254742         1937.15
# ...

# %%
country = pd.read_csv('C:\\Users\\ChrisBo\\Documents\\GitHub\\CSChallange\\country.csv', sep=',')
country.head()
#country[country['country_name'].str.contains('Korea')]
#cpi[cpi['Country'].str.contains('Korea')]
# Out:
#    country_id country_name
# 0           1  Afghanistan
# 1           2      Albania
# 2           3      Algeria
# 3           4      Andorra
# 4           5       Angola

# %%
'aaa'=='aab'
# Out:
# False

# %%
#lambda x: any(k in x for k in cpi.country)
countryList1=cpi['Country'].tolist()
countryList2=country['country_name'].tolist()

len(countryList1)
countryList1[1]


for i in range(len(countryList1))
    if
# Out:
# True
